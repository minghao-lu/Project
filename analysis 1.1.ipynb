# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot: Distribution of social media time per day by geographic area
plt.figure(figsize=(12, 8))
sns.countplot(
    data=data,
    x='connection_social_media_time_per_day',
    hue='geo_rural_urban',
    order=['Less than 10 minutes per day', '10-30 minutes per day', 
           '31-60 minutes per day', '1-2 hours per day', 
           '2-3 hours per day', 'More than 3 hours per day'],
    palette="pastel"
)
plt.title("Social Media Time Per Day by Geographic Area")
plt.xlabel("Social Media Time (per day)")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Geographic Area", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
